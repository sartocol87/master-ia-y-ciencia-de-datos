# %%
import pandas as pd
print("Pandas version:", pd.__version__)
# Out:
# Pandas version: 2.2.2

# %%
df =pd.read_csv("personas.csv" , sep=";")

# Mostrar las primeras filas del DataFrame
print(df.head())
df.head()
# Out:
#    Nombre  Edad     Ciudad  Unnamed: 3
# 0    Juan    26     Ibague         NaN
# 1   Pedro    56  Monterrey         NaN
# 2  Camilo    15     Bogota         NaN
#    Nombre  Edad     Ciudad  Unnamed: 3
# 0    Juan    26     Ibague         NaN
# 1   Pedro    56  Monterrey         NaN
# 2  Camilo    15     Bogota         NaN

# %%
# calcula la edad promedio de las personas en el DataFrame
promedio = df['Edad'].mean()
print(f"La edad promedio es: {promedio}")
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[2], line 2
#       1 # calcula la edad promedio de las personas en el DataFrame
# ----> 2 promedio = df['Edad'].mean()
#       3 print(f"La edad promedio es: {promedio}")
#
# NameError: name 'df' is not defined

# %%
# Verificar si hay valores nulos en el DataFrame
df.isnull().sum()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[1], line 2
#       1 # Verificar si hay valores nulos en el DataFrame
# ----> 2 df.isnull().sum()
#
# NameError: name 'df' is not defined
